# %%
# Copyright (c) Facebook, Inc. and its affiliates. All Rights Reserved.

# %% [markdown]
# ## Introduction
# This tutorial goes through how to use model zoo provided by PytorchVideo/Accelerator. To use model zoo in PytorchVideo/Accelerator, we should generally follow several steps:
# - Use model builder to build selected model;
# - Load pretrain checkpoint;
# - (Optional) Finetune;
# - Deploy.
#
# Before we start, let's install PytorchVideo.

# %%
# !pip install pytorchvideo

# %% [markdown]
# ## Use model builder to build selected model
# We use model builder in PytorchVideo/Accelerator model zoo to build pre-defined efficient model. Here we use EfficientX3D-XS (for mobile_cpu) as an example. For more available models and details, please refer to [this page].
#
# EfficientX3D-XS is an implementation of X3D-XS network as described in [X3D paper](https://arxiv.org/abs/2004.04730) using efficient blocks. It is arithmetically equivalent with X3D-XS, but our benchmark on mobile phone shows 4.6X latency reduction compared with vanilla implementation.
#
# In order to build EfficientX3D-XS, we simply do the following:

# %%
from pytorchvideo.models.accelerator.mobile_cpu.efficient_x3d import EfficientX3d
model_efficient_x3d_xs = EfficientX3d(expansion='XS', head_act='identity')

# %% [markdown]
# Note that now the efficient blocks in the model are in original form, so the model is good for further training.

# %% [markdown]
# ## Load pretrain checkpoint and (optional) finetune
# For each model in model zoo, we provide pretrain checkpoint state_dict for model in original form. See [this page] for details about checkpoints and where to download them.

# %%
from torch.hub import load_state_dict_from_url
checkpoint_path = 'https://dl.fbaipublicfiles.com/pytorchvideo/model_zoo/kinetics/efficient_x3d_xs_original_form.pyth'
checkpoint = load_state_dict_from_url(checkpoint_path)

model_efficient_x3d_xs.load_state_dict(checkpoint)
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/pytorchvideo/model_zoo/kinetics/efficient_x3d_xs_original_form.pyth" to /home/thisiswooyeol/.cache/torch/hub/checkpoints/efficient_x3d_xs_original_form.pyth
#   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# <All keys matched successfully>

# %% [markdown]
# Now the model is ready for fine-tune.

# %% [markdown]
# ## Deploy
# Now the model is ready to deploy. First of all, let's convert the model into deploy form. In order to do that, we need to use `convert_to_deployable_form` utility and provide an example input tensor to the model. Note that once the model is converted into deploy form, the input size should be the same as the example input tensor size during conversion.

# %%
import torch
from pytorchvideo.accelerator.deployment.mobile_cpu.utils.model_conversion import (
    convert_to_deployable_form,
)
input_blob_size = (1, 3, 4, 160, 160)
input_tensor = torch.randn(input_blob_size)
model_efficient_x3d_xs_deploy = convert_to_deployable_form(model_efficient_x3d_xs, input_tensor)

# %% [markdown]
# We can see that the network graph has been changed after conversion, which did kernel and graph optimization.

# %%
print(model_efficient_x3d_xs_deploy)
# Out:
# EfficientX3d(
#   (s1): Sequential(
#     (pathway0_stem_conv_xy): Conv3dTemporalKernel1BnAct(
#       (kernel): Sequential(
#         (conv): _Conv3dTemporalKernel1Decomposed(
#           (conv2d_eq): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         )
#         (act): Identity(
#           (act): Identity()
#         )
#       )
#     )
#     (pathway0_stem_conv): Conv3d5x1x1BnAct(
#       (kernel): Sequential(
#         (conv): _Conv3dTemporalKernel5Decomposed(
#           (_conv2d_0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), groups=24, bias=False)
#           (_conv2d_1): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), groups=24, bias=False)
#           (_conv2d_2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), groups=24)
#           (_conv2d_3): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), groups=24, bias=False)
#           (_conv2d_4): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), groups=24, bias=False)
#           (_add_funcs): ModuleList(
#             (0): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (1): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (2): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (3): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (4): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (5): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (6): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (7): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (8): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#             (9): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#           (_cat_func): FloatFunctional(
#             (activation_post_process): Identity()
#           )
#         )
#         (bn): Identity()
#         (act): ReLU(
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (s2): Sequential(
#     (pathway0_res0): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (_res_proj): Conv3dTemporalKernel1BnAct(
#         (kernel): Sequential(
#           (conv): _Conv3dTemporalKernel1Decomposed(
#             (conv2d_eq): Conv2d(24, 24, kernel_size=(1, 1), stride=(2, 2))
#           )
#           (bn): Identity()
#           (act): Identity(
#             (act): Identity()
#           )
#         )
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(24, 54, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(54, 54, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=54, bias=False)
#               (_conv2d_3_3_2): Conv2d(54, 54, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=54, bias=False)
#               (_conv2d_3_3_1): Conv2d(54, 54, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=54)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=54, out_features=8, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=8, out_features=54, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(54, 24, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res1): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(24, 54, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#               (_conv2d_3_3_2): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#               (_conv2d_3_3_1): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(54, 24, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res2): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(24, 54, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#               (_conv2d_3_3_2): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#               (_conv2d_3_3_1): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=54, out_features=8, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=8, out_features=54, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(54, 24, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#   )
#   (s3): Sequential(
#     (pathway0_res0): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (_res_proj): Conv3dTemporalKernel1BnAct(
#         (kernel): Sequential(
#           (conv): _Conv3dTemporalKernel1Decomposed(
#             (conv2d_eq): Conv2d(24, 48, kernel_size=(1, 1), stride=(2, 2))
#           )
#           (bn): Identity()
#           (act): Identity(
#             (act): Identity()
#           )
#         )
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(24, 108, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(108, 108, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_2): Conv2d(108, 108, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_1): Conv2d(108, 108, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=108)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=108, out_features=8, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=8, out_features=108, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res1): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(48, 108, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_2): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_1): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res2): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(48, 108, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_2): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_1): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=108, out_features=8, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=8, out_features=108, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res3): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(48, 108, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_2): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_1): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res4): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(48, 108, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_2): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#               (_conv2d_3_3_1): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=108, out_features=8, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=8, out_features=108, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(108, 48, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#   )
#   (s4): Sequential(
#     (pathway0_res0): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (_res_proj): Conv3dTemporalKernel1BnAct(
#         (kernel): Sequential(
#           (conv): _Conv3dTemporalKernel1Decomposed(
#             (conv2d_eq): Conv2d(48, 96, kernel_size=(1, 1), stride=(2, 2))
#           )
#           (bn): Identity()
#           (act): Identity(
#             (act): Identity()
#           )
#         )
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(48, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=216, out_features=16, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=16, out_features=216, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res1): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(96, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res2): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(96, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=216, out_features=16, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=16, out_features=216, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res3): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(96, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res4): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(96, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=216, out_features=16, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=16, out_features=216, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res5): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(96, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(216, 96, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res6): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(96, 216, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_2): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#               (_conv2d_3_3_1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
# ...
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_2): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=432, out_features=32, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=32, out_features=432, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res3): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(192, 432, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_2): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res4): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(192, 432, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_2): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=432, out_features=32, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=32, out_features=432, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res5): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(192, 432, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_2): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#     (pathway0_res6): X3dBottleneckBlock(
#       (_residual_add_func): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#       (final_act): ReLU(
#         (act): ReLU(inplace=True)
#       )
#       (layers): Sequential(
#         (conv_0): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): ConvReLU2d(
#                 (0): Conv2d(192, 432, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#               )
#               (bn): Identity()
#               (act): ReLU(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#         (conv_1): Conv3d3x3x3DwBnAct(
#           (kernel): Sequential(
#             (conv): _Conv3dTemporalKernel3Decomposed(
#               (_conv2d_3_3_0): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_2): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#               (_conv2d_3_3_1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432)
#               (_add_funcs): ModuleList(
#                 (0): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (1): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (2): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (3): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (4): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#                 (5): FloatFunctional(
#                   (activation_post_process): Identity()
#                 )
#               )
#               (_cat_func): FloatFunctional(
#                 (activation_post_process): Identity()
#               )
#             )
#             (bn): Identity()
#             (act): Identity(
#               (act): Identity()
#             )
#           )
#         )
#         (se): SqueezeExcitation(
#           (se): _SkipConnectMul(
#             (layer): Sequential(
#               (0): AdaptiveAvgPool3d(output_size=1)
#               (1): _Reshape()
#               (2): Linear(in_features=432, out_features=32, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=32, out_features=432, bias=True)
#               (5): Sigmoid()
#               (6): _Reshape()
#             )
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (act_func_1): Swish(
#           (act): _NaiveSwish(
#             (mul_func): FloatFunctional(
#               (activation_post_process): Identity()
#             )
#           )
#         )
#         (conv_2): Conv3dPwBnAct(
#           (kernel): Sequential(
#             (0): _Reshape()
#             (1): Sequential(
#               (conv): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1))
#               (bn): Identity()
#               (act): Identity(
#                 (act): Identity()
#               )
#             )
#             (2): _Reshape()
#           )
#         )
#       )
#     )
#   )
#   (head): Sequential(
#     (conv_5): Conv3dPwBnAct(
#       (kernel): Sequential(
#         (0): _Reshape()
#         (1): Sequential(
#           (conv): ConvReLU2d(
#             (0): Conv2d(192, 432, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (bn): Identity()
#           (act): ReLU(
#             (act): Identity()
#           )
#         )
#         (2): _Reshape()
#       )
#     )
#     (avg_pool): AdaptiveAvgPool3dOutSize1(
#       (pool): AvgPool3d(kernel_size=(4, 5, 5), stride=(4, 5, 5), padding=0)
#     )
#     (lin_5): Conv3dPwBnAct(
#       (kernel): Sequential(
#         (0): _Reshape()
#         (1): Sequential(
#           (conv): ConvReLU2d(
#             (0): Conv2d(432, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): ReLU(inplace=True)
#           )
#           (act): ReLU(
#             (act): Identity()
#           )
#         )
#         (2): _Reshape()
#       )
#     )
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (projection): FullyConnected(
#     (model): Linear(in_features=2048, out_features=400, bias=True)
#   )
#   (act): Identity(
#     (act): Identity()
#   )
# )

# %% [markdown]
# Next we have two options: either deploy floating point model, or quantize model into int8 and then deploy.
#
# Let's first assume we want to deploy floating point model. In this case, all we need to do is to export jit trace and then apply `optimize_for_mobile` for final optimization.

# %%
from torch.utils.mobile_optimizer import (
    optimize_for_mobile,
)
traced_model = torch.jit.trace(model_efficient_x3d_xs_deploy, input_tensor, strict=False)
traced_model_opt = optimize_for_mobile(traced_model)
# Here we can save the traced_model_opt to JIT file using traced_model_opt.save(<file_path>)
traced_model_opt.save('/home/thisiswooyeol/PycharmProjects/pytorchvideo/tutorials/accelerator/efficient_x3d_xs_tutorial_float.pt')

# %% [markdown]
# Alternatively, we may also want to deploy a quantized model. Efficient blocks are quantization-friendly by design - just wrap the model in deploy form with `QuantStub/DeQuantStub` and it is ready for Pytorch eager mode quantization.

# %%
import torch.nn as nn
# Wrapper class for adding QuantStub/DeQuantStub.
class quant_stub_wrapper(nn.Module):
    def __init__(self, module_in):
        super().__init__()
        self.quant = torch.quantization.QuantStub()
        self.model = module_in
        self.dequant = torch.quantization.DeQuantStub()
    def forward(self, x):
        x = self.quant(x)
        x = self.model(x)
        x = self.dequant(x)
        return x

# %%
model_efficient_x3d_xs_deploy_quant_stub_wrapper = quant_stub_wrapper(model_efficient_x3d_xs_deploy)

# %% [markdown]
# Preparation step of quantization. Fusion has been done for efficient blocks automatically during `convert_to_deployable_form`, so we can just proceed to `torch.quantization.prepare`

# %%
model_efficient_x3d_xs_deploy_quant_stub_wrapper.qconfig = torch.quantization.default_qconfig
model_efficient_x3d_xs_deploy_quant_stub_wrapper_prepared = torch.quantization.prepare(model_efficient_x3d_xs_deploy_quant_stub_wrapper)
# Out:
# /home/thisiswooyeol/anaconda3/envs/pytorchvideo/lib/python3.7/site-packages/torch/quantization/observer.py:123: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   reduce_range will be deprecated in a future release of PyTorch."

# %% [markdown]
# Calibration and quantization. After preparation we will do calibration of quantization by feeding calibration dataset (skipped here) and then do quantization.

# %%
# calibration is skipped here.
model_efficient_x3d_xs_deploy_quant_stub_wrapper_quantized = torch.quantization.convert(model_efficient_x3d_xs_deploy_quant_stub_wrapper_prepared)
# Out:
# /home/thisiswooyeol/anaconda3/envs/pytorchvideo/lib/python3.7/site-packages/torch/quantization/observer.py:245: UserWarning: must run observer before calling calculate_qparams.                                        Returning default scale and zero point
#   Returning default scale and zero point "

# %% [markdown]
# Then we can export trace of int8 model and deploy on mobile devices.

# %%
traced_model_int8 = torch.jit.trace(model_efficient_x3d_xs_deploy_quant_stub_wrapper_quantized, input_tensor, strict=False)
traced_model_int8_opt = optimize_for_mobile(traced_model_int8)
# Here we can save the traced_model_opt to JIT file using traced_model_int8_opt.save(<file_path>)
traced_model_int8_opt.save('/home/thisiswooyeol/PycharmProjects/pytorchvideo/tutorials/accelerator/efficient_x3d_xs_tutorial_int8.pt')
